# %% [markdown]
# # Building a Multivariate Dataset From Your Model Objects
#
# The purpose of this Notebook is to use the Disease Propogation Objects to build a dataset testing variations in the mitigation methods. The output of this Notebook will be a csv file that contains the results from multple runs of the various interactions.
#
# ## Steps:
# 1. Add the Person, Population, and Community Objects
# 2. Create a function that allows the Community object interventions parameters to be tested over the range of 0 to that number (Ex. Population Size, Number of Interactions, Percentage Masked). **NOTE: make sure to add any custom interventions you may have added.**
# 3. Alter the code to ouput to a csv file
# 4. Run the simulation to create your dataset.
#
#
# ## Step 1. Add our Person, Population, and Community Class Objects
#
# #### Person Object

# %%
import numpy as np
import random

# Person Object AKA Joe
class Person(object):
    def __init__(self):
        self.status = "Susceptible"
        self.days_sick = 0
        self.sickness_rate = 10
        self.Interaction = []
        self.masked = False
        
    def maskUp(self, wears_mask):
        if (wears_mask):
            self.set_sickness_rate(self.sickness_rate/2)
            self.masked = True
    
    def set_sickness_rate(self, new_rate):
        self.sickness_rate = new_rate
    
    def infect(self, number_of_days_sick):
        self.status = "Infected"
        self.days_sick = number_of_days_sick
    
    def recover(self):
        self.status = "Recovered"
        self.days_sick = 0
    
    def update(self):
        if (self.status == "Susceptible"):
            self.roll_for_infection()
            
        elif (self.status == "Infected"):            
            self.days_sick = self.days_sick - 1
            if (self.days_sick <= 0):
                self.recover()
    
    def update_days_sick(self):
        if (self.status == "Infected"):            
            self.days_sick = self.days_sick - 1
            if (self.days_sick <= 0):
                self.recover()
            

            
    def roll_for_infection(self):
        is_sick = (random.randint(0,101) < self.sickness_rate)
        if (is_sick):
            self.infect(4)

# %% [markdown]
# #### Population Community

# %%
# Population Object
class Population:
    def __init__(self, number=100, interaction=10, percentage_masked=0):
        self.People = []
        self.number = number
        self.interaction = interaction
        self.percentage_masked = percentage_masked
        
        if (number < 100):
            self.number = 100
        
        if (interaction < 10):
            self.interaction = 10
        
        ##build our population
        patient_Zero = Person()
        patient_Zero.infect(5)
        
        self.People.append(patient_Zero)
        
        for i in range(0,number):
            p = Person()
            if (i < number*(self.percentage_masked/100.0) and self.percentage_masked>0):
                p.maskUp(True)
                
            self.People.append(p)

               
            
    def number_of_sick(self):
        sick_Count = 0
        for j in self.People:
            if (j.status == "Infected"):
                sick_Count = sick_Count + 1
                
        return sick_Count
    
    def number_of_recovered(self):
        recovered_Count = 0
        for j in self.People:
            if (j.status == "Recovered"):
                recovered_Count = recovered_Count + 1
        
        return recovered_Count
    
    def number_of_susceptible(self):
        susceptible_Count = 0
        for j in self.People:
            if (j.status == "Susceptible"):
                susceptible_Count = susceptible_Count + 1
                
        return susceptible_Count
    
    def number_masked(self):
        masked_Count = 0
        for j in self.People:
            if (j.masked):
                masked_Count = masked_Count + 1
        
        return masked_Count
    
    def number_masked_sick(self):
        masked_SickCount = 0
        for j in self.People:
            if (j.masked and j.status == "Infected"):
                masked_SickCount = masked_SickCount + 1
        
        return masked_SickCount
    
    ## Here's the brains of the Population class (and our code)
    ## the update will be ran everyday (meaning, every iteration of our while loop)
    ## build interaction tables (who interacted with whom)
    ## if marked sick they must roll to see if (one per interaction)
    ## if I interacted with 10 people, each of them must roll and vice versa if they
    ## they were marked as infected
    def update(self):
        ## people who are might get sick
        might_Get_Sick = []
        
        for person in self.People:
            
            #clear out your interactions per day
            person.Interaction = []
            
            ##These are the n number of people that you interact with
            for i in range(0, self.interaction):
                r = random.randint(0,self.number)
                person.Interaction.append(r)
                
            ##if "person" is Infected, every single person they interacted with might get sick
            if (person.status == "Infected"):
                person.update_days_sick()
                
                for m in person.Interaction:
                    if (self.People[m].status == "Susceptible"): #only susceptible people can get sick
                        might_Get_Sick.append(self.People[m])
            
            ##if "person" is susceptible and they interact w/ someone who is "infected" 
            ##person gets added to the "might get sick"
            if (person.status == "Susceptible"):
                for m in person.Interaction:
                    if (self.People[m].status == "Infected"):
                        might_Get_Sick.append(person)
            
        ##Now! We're going to roll through our "Might Get Sick" and they each roll a die
        ##this is only a list of susceptible people
        for p in might_Get_Sick:
            p.roll_for_infection()

# %% [markdown]
# #### Person Community

# %%
# Define the Community
# Population( size_of_population, number_of_interactions, percentage_wearing_masks)
myCommunity = Population(8000,10,50)
day = 0
my_plot = []
number_sick = myCommunity.number_of_sick()
while (number_sick > 0):
    number_sick = myCommunity.number_of_sick()
    number_recovered = myCommunity.number_of_recovered()
    number_masked = myCommunity.number_masked()
    number_masked_sick = myCommunity.number_masked_sick()
    
    my_plot.append([day, number_sick, number_recovered])
    
    if (myCommunity.percentage_masked > 0):
        print ("day:", day, "Number of sick:", number_sick, "Hosptalized:", number_sick*(.04), "Sick Mask Wearers:", number_masked_sick, "Mask Wearers:", number_masked)
    else:
        print ("day:", day, "Number of sick:", number_sick)
    
    day = day+1
    myCommunity.update()

#print ("day:", day, "Number of sick:", myCommunity.number_of_sick())
print ("Number recovered:", myCommunity.number_of_recovered())
print ("Number susceptible:", myCommunity.number_of_susceptible())
# Out:
# day: 0 Number of sick: 1 Hosptalized: 0.04 Sick Mask Wearers: 0 Mask Wearers: 4000
# day: 1 Number of sick: 6 Hosptalized: 0.24 Sick Mask Wearers: 1 Mask Wearers: 4000
# day: 2 Number of sick: 14 Hosptalized: 0.56 Sick Mask Wearers: 5 Mask Wearers: 4000
# day: 3 Number of sick: 41 Hosptalized: 1.6400000000000001 Sick Mask Wearers: 13 Mask Wearers: 4000
# day: 4 Number of sick: 92 Hosptalized: 3.68 Sick Mask Wearers: 35 Mask Wearers: 4000
# day: 5 Number of sick: 224 Hosptalized: 8.96 Sick Mask Wearers: 72 Mask Wearers: 4000
# day: 6 Number of sick: 549 Hosptalized: 21.96 Sick Mask Wearers: 184 Mask Wearers: 4000
# day: 7 Number of sick: 1236 Hosptalized: 49.44 Sick Mask Wearers: 438 Mask Wearers: 4000
# day: 8 Number of sick: 2496 Hosptalized: 99.84 Sick Mask Wearers: 929 Mask Wearers: 4000
# day: 9 Number of sick: 4243 Hosptalized: 169.72 Sick Mask Wearers: 1705 Mask Wearers: 4000
# day: 10 Number of sick: 5644 Hosptalized: 225.76 Sick Mask Wearers: 2493 Mask Wearers: 4000
# day: 11 Number of sick: 5911 Hosptalized: 236.44 Sick Mask Wearers: 2866 Mask Wearers: 4000
# day: 12 Number of sick: 5031 Hosptalized: 201.24 Sick Mask Wearers: 2691 Mask Wearers: 4000
# day: 13 Number of sick: 3328 Hosptalized: 133.12 Sick Mask Wearers: 2033 Mask Wearers: 4000
# day: 14 Number of sick: 1656 Hosptalized: 66.24 Sick Mask Wearers: 1187 Mask Wearers: 4000
# day: 15 Number of sick: 698 Hosptalized: 27.92 Sick Mask Wearers: 574 Mask Wearers: 4000
# day: 16 Number of sick: 274 Hosptalized: 10.96 Sick Mask Wearers: 242 Mask Wearers: 4000
# day: 17 Number of sick: 94 Hosptalized: 3.7600000000000002 Sick Mask Wearers: 88 Mask Wearers: 4000
# day: 18 Number of sick: 33 Hosptalized: 1.32 Sick Mask Wearers: 31 Mask Wearers: 4000
# day: 19 Number of sick: 10 Hosptalized: 0.4 Sick Mask Wearers: 9 Mask Wearers: 4000
# day: 20 Number of sick: 3 Hosptalized: 0.12 Sick Mask Wearers: 3 Mask Wearers: 4000
# day: 21 Number of sick: 1 Hosptalized: 0.04 Sick Mask Wearers: 1 Mask Wearers: 4000
# day: 22 Number of sick: 0 Hosptalized: 0.0 Sick Mask Wearers: 0 Mask Wearers: 4000
# Number recovered: 7896
# Number susceptible: 105

# %% [markdown]
# # 2. Make a function that allows the interventions to be easily tested
#
# Create a function that allows the Community object interventions parameters to be tested over the range of 0 to that number (Ex. Population Size, Number of Interactions, Percentage Masked).

# %%
def myCommunityTests(pop_test, interactions_test, masked_test):
    # Population( size_of_population, number_of_interactions, percentage_wearing_masks)
    myCommunity = Population(pop_test,interactions_test,masked_test)
    day = 0
    my_plot = []
    number_sick = myCommunity.number_of_sick()
    while (number_sick > 0):
        number_sick = myCommunity.number_of_sick()
        number_recovered = myCommunity.number_of_recovered()
        number_masked = myCommunity.number_masked()
        number_masked_sick = myCommunity.number_masked_sick()
    
        my_plot.append([day, number_sick, number_recovered])
    
        if (myCommunity.percentage_masked > 0):
            print ("day:", day, "Number of sick:", number_sick, "Hosptalized:", number_sick*(.04), "Sick Mask Wearers:", number_masked_sick, "Mask Wearers:", number_masked)
        else:
            print ("day:", day, "Number of sick:", number_sick)
    
        day = day+1
        myCommunity.update()

    #print ("day:", day, "Number of sick:", myCommunity.number_of_sick())
    print ("Number recovered:", myCommunity.number_of_recovered())
    print ("Number susceptible:", myCommunity.number_of_susceptible())

# %%
myCommunityTests(500, 3, 40)
# Out:
# day: 0 Number of sick: 1 Hosptalized: 0.04 Sick Mask Wearers: 0 Mask Wearers: 200
# day: 1 Number of sick: 3 Hosptalized: 0.12 Sick Mask Wearers: 0 Mask Wearers: 200
# day: 2 Number of sick: 9 Hosptalized: 0.36 Sick Mask Wearers: 0 Mask Wearers: 200
# day: 3 Number of sick: 28 Hosptalized: 1.12 Sick Mask Wearers: 6 Mask Wearers: 200
# day: 4 Number of sick: 63 Hosptalized: 2.52 Sick Mask Wearers: 12 Mask Wearers: 200
# day: 5 Number of sick: 134 Hosptalized: 5.36 Sick Mask Wearers: 32 Mask Wearers: 200
# day: 6 Number of sick: 246 Hosptalized: 9.84 Sick Mask Wearers: 69 Mask Wearers: 200
# day: 7 Number of sick: 340 Hosptalized: 13.6 Sick Mask Wearers: 108 Mask Wearers: 200
# day: 8 Number of sick: 376 Hosptalized: 15.040000000000001 Sick Mask Wearers: 142 Mask Wearers: 200
# day: 9 Number of sick: 337 Hosptalized: 13.48 Sick Mask Wearers: 144 Mask Wearers: 200
# day: 10 Number of sick: 229 Hosptalized: 9.16 Sick Mask Wearers: 114 Mask Wearers: 200
# day: 11 Number of sick: 120 Hosptalized: 4.8 Sick Mask Wearers: 73 Mask Wearers: 200
# day: 12 Number of sick: 53 Hosptalized: 2.12 Sick Mask Wearers: 37 Mask Wearers: 200
# day: 13 Number of sick: 20 Hosptalized: 0.8 Sick Mask Wearers: 17 Mask Wearers: 200
# day: 14 Number of sick: 10 Hosptalized: 0.4 Sick Mask Wearers: 10 Mask Wearers: 200
# day: 15 Number of sick: 6 Hosptalized: 0.24 Sick Mask Wearers: 6 Mask Wearers: 200
# day: 16 Number of sick: 2 Hosptalized: 0.08 Sick Mask Wearers: 2 Mask Wearers: 200
# day: 17 Number of sick: 0 Hosptalized: 0.0 Sick Mask Wearers: 0 Mask Wearers: 200
# Number recovered: 494
# Number susceptible: 7

# %% [markdown]
# ## 3. Alter the code to ouput to a csv file

# %%
# Alter the myCommunityTests function to ouput wanted data to a csv

#Ex: Population_Size, Number_Interactions, Percentage_Masked, Total_Days, Number_Recovered, Number_Suceptible, Max_Sick, Max_Hospitalized
import pandas as pd

def myCommunityTests_toDict(pop_test, interactions_test, masked_test, hospitalization_rate = .04):
    # Population( size_of_population, number_of_interactions, percentage_wearing_masks)
    myCommunity = Population(pop_test,interactions_test,masked_test)
    day = 0
    my_plot = []
    simulation_sumary = {
        "Population_Size" : pop_test,
        "Number_Interactions" : interactions_test,
        "Percentage_Masked" : masked_test,
        "Hospitalization_Rate" : hospitalization_rate
    }
    
    number_sick = myCommunity.number_of_sick()
    while (number_sick > 0):
        number_sick = myCommunity.number_of_sick()
        number_recovered = myCommunity.number_of_recovered()
        number_masked = myCommunity.number_masked()
        number_masked_sick = myCommunity.number_masked_sick()
    
        my_plot.append([day, number_sick, number_recovered, number_sick*(hospitalization_rate), number_masked_sick, number_masked])
    
        #if (myCommunity.percentage_masked > 0):
            #print ("day:", day, "Number of sick:", number_sick, "Hosptalized:", number_sick*(hospitalization_rate), "Sick Mask Wearers:", number_masked_sick, "Mask Wearers:", number_masked)
        #else:
            #print ("day:", day, "Number of sick:", number_sick)
    
        day = day+1
        myCommunity.update()
    
    dataset = pd.DataFrame(my_plot, columns=['day','number_sick', 'number_recovered','hosptalized', 'sick_mask_wearers','mask_wearers' ])
    #print ("day:", day, "Number of sick:", myCommunity.number_of_sick())
    #print ("Number recovered:", myCommunity.number_of_recovered())
    simulation_sumary["recovered"] = myCommunity.number_of_recovered()
    #print ("Number susceptible:", myCommunity.number_of_susceptible())
    simulation_sumary["susceptible"] = myCommunity.number_of_susceptible()
    #print (dataset.head())
    simulation_sumary["total_days"] = dataset["day"].max()
    simulation_sumary["max_sick"] = dataset["number_sick"].max()
    simulation_sumary["max_hosptalized"] = dataset["hosptalized"].max()
    simulation_sumary["max_sick_mask_wearers"] = dataset["sick_mask_wearers"].max()
    simulation_sumary["total_mask_wearers"] = dataset["mask_wearers"].max()
    
    print(simulation_sumary)
    return simulation_sumary

# %%
myCommunityTests_toDict(5000, 5, 50)
# Out:
# {'Population_Size': 5000, 'Number_Interactions': 5, 'Percentage_Masked': 50, 'Hospitalization_Rate': 0.04, 'recovered': 4936, 'susceptible': 65, 'total_days': 25, 'max_sick': 3616, 'max_hosptalized': 144.64000000000001, 'max_sick_mask_wearers': 1770, 'total_mask_wearers': 2500}
# {'Population_Size': 5000,
#  'Number_Interactions': 5,
#  'Percentage_Masked': 50,
#  'Hospitalization_Rate': 0.04,
#  'recovered': 4936,
#  'susceptible': 65,
#  'total_days': 25,
#  'max_sick': 3616,
#  'max_hosptalized': 144.64000000000001,
#  'max_sick_mask_wearers': 1770,
#  'total_mask_wearers': 2500}

# %% [markdown]
# # 4. Now lets run our simulation with a range of values for our interventions

# %%
import csv

test_population = 3000
maximum_interactions = 10
maximum_mask_percentage = 20
hospital_rate = .4

# Name of the output csv file
filename = "mycsvfile.csv"


for i in range(0, maximum_interactions, 1):
     for m in range(0, maximum_mask_percentage, 1):
        
          sim_data = myCommunityTests_toDict(test_population, i, m, hospital_rate)
          print(sim_data)
    
          if (i == 0 and m == 0):
             with open(filename, 'w') as f:  
                 w = csv.DictWriter(f, sim_data.keys())
                 w.writeheader()
          else:
              with open(filename, 'a') as f:  # You will need 'wb' mode in Python 2.x
                w = csv.DictWriter(f, sim_data.keys())
                w.writerow(sim_data)
# Out:
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 3001, 'susceptible': 0, 'total_days': 16, 'max_sick': 2565, 'max_hosptalized': 1026.0, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 3001, 'susceptible': 0, 'total_days': 16, 'max_sick': 2565, 'max_hosptalized': 1026.0, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 3000, 'susceptible': 1, 'total_days': 17, 'max_sick': 2616, 'max_hosptalized': 1046.4, 'max_sick_mask_wearers': 26, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 3000, 'susceptible': 1, 'total_days': 17, 'max_sick': 2616, 'max_hosptalized': 1046.4, 'max_sick_mask_wearers': 26, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 22, 'max_sick': 2604, 'max_hosptalized': 1041.6000000000001, 'max_sick_mask_wearers': 44, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 22, 'max_sick': 2604, 'max_hosptalized': 1041.6000000000001, 'max_sick_mask_wearers': 44, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 19, 'max_sick': 2546, 'max_hosptalized': 1018.4000000000001, 'max_sick_mask_wearers': 70, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 19, 'max_sick': 2546, 'max_hosptalized': 1018.4000000000001, 'max_sick_mask_wearers': 70, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 18, 'max_sick': 2504, 'max_hosptalized': 1001.6, 'max_sick_mask_wearers': 92, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 18, 'max_sick': 2504, 'max_hosptalized': 1001.6, 'max_sick_mask_wearers': 92, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2567, 'max_hosptalized': 1026.8, 'max_sick_mask_wearers': 113, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2567, 'max_hosptalized': 1026.8, 'max_sick_mask_wearers': 113, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2523, 'max_hosptalized': 1009.2, 'max_sick_mask_wearers': 143, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2523, 'max_hosptalized': 1009.2, 'max_sick_mask_wearers': 143, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 18, 'max_sick': 2520, 'max_hosptalized': 1008.0, 'max_sick_mask_wearers': 162, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 18, 'max_sick': 2520, 'max_hosptalized': 1008.0, 'max_sick_mask_wearers': 162, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 17, 'max_sick': 2514, 'max_hosptalized': 1005.6, 'max_sick_mask_wearers': 189, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 17, 'max_sick': 2514, 'max_hosptalized': 1005.6, 'max_sick_mask_wearers': 189, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 19, 'max_sick': 2551, 'max_hosptalized': 1020.4000000000001, 'max_sick_mask_wearers': 217, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 19, 'max_sick': 2551, 'max_hosptalized': 1020.4000000000001, 'max_sick_mask_wearers': 217, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2476, 'max_hosptalized': 990.4000000000001, 'max_sick_mask_wearers': 224, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2476, 'max_hosptalized': 990.4000000000001, 'max_sick_mask_wearers': 224, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 17, 'max_sick': 2554, 'max_hosptalized': 1021.6, 'max_sick_mask_wearers': 258, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 17, 'max_sick': 2554, 'max_hosptalized': 1021.6, 'max_sick_mask_wearers': 258, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2475, 'max_hosptalized': 990.0, 'max_sick_mask_wearers': 273, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2475, 'max_hosptalized': 990.0, 'max_sick_mask_wearers': 273, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2990, 'susceptible': 11, 'total_days': 19, 'max_sick': 2517, 'max_hosptalized': 1006.8000000000001, 'max_sick_mask_wearers': 309, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2990, 'susceptible': 11, 'total_days': 19, 'max_sick': 2517, 'max_hosptalized': 1006.8000000000001, 'max_sick_mask_wearers': 309, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 23, 'max_sick': 2452, 'max_hosptalized': 980.8000000000001, 'max_sick_mask_wearers': 323, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 23, 'max_sick': 2452, 'max_hosptalized': 980.8000000000001, 'max_sick_mask_wearers': 323, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2989, 'susceptible': 12, 'total_days': 20, 'max_sick': 2473, 'max_hosptalized': 989.2, 'max_sick_mask_wearers': 337, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2989, 'susceptible': 12, 'total_days': 20, 'max_sick': 2473, 'max_hosptalized': 989.2, 'max_sick_mask_wearers': 337, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2486, 'max_hosptalized': 994.4000000000001, 'max_sick_mask_wearers': 389, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2486, 'max_hosptalized': 994.4000000000001, 'max_sick_mask_wearers': 389, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2982, 'susceptible': 19, 'total_days': 19, 'max_sick': 2424, 'max_hosptalized': 969.6, 'max_sick_mask_wearers': 377, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2982, 'susceptible': 19, 'total_days': 19, 'max_sick': 2424, 'max_hosptalized': 969.6, 'max_sick_mask_wearers': 377, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 17, 'max_sick': 2514, 'max_hosptalized': 1005.6, 'max_sick_mask_wearers': 408, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 17, 'max_sick': 2514, 'max_hosptalized': 1005.6, 'max_sick_mask_wearers': 408, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2982, 'susceptible': 19, 'total_days': 22, 'max_sick': 2439, 'max_hosptalized': 975.6, 'max_sick_mask_wearers': 436, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 0, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2982, 'susceptible': 19, 'total_days': 22, 'max_sick': 2439, 'max_hosptalized': 975.6, 'max_sick_mask_wearers': 436, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 16, 'max_sick': 2595, 'max_hosptalized': 1038.0, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 16, 'max_sick': 2595, 'max_hosptalized': 1038.0, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 16, 'max_sick': 2559, 'max_hosptalized': 1023.6, 'max_sick_mask_wearers': 25, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 16, 'max_sick': 2559, 'max_hosptalized': 1023.6, 'max_sick_mask_wearers': 25, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 16, 'max_sick': 2617, 'max_hosptalized': 1046.8, 'max_sick_mask_wearers': 45, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 16, 'max_sick': 2617, 'max_hosptalized': 1046.8, 'max_sick_mask_wearers': 45, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 16, 'max_sick': 2596, 'max_hosptalized': 1038.4, 'max_sick_mask_wearers': 71, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 16, 'max_sick': 2596, 'max_hosptalized': 1038.4, 'max_sick_mask_wearers': 71, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2597, 'max_hosptalized': 1038.8, 'max_sick_mask_wearers': 97, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2597, 'max_hosptalized': 1038.8, 'max_sick_mask_wearers': 97, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 16, 'max_sick': 2572, 'max_hosptalized': 1028.8, 'max_sick_mask_wearers': 120, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 16, 'max_sick': 2572, 'max_hosptalized': 1028.8, 'max_sick_mask_wearers': 120, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 18, 'max_sick': 2534, 'max_hosptalized': 1013.6, 'max_sick_mask_wearers': 139, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 18, 'max_sick': 2534, 'max_hosptalized': 1013.6, 'max_sick_mask_wearers': 139, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2594, 'max_hosptalized': 1037.6000000000001, 'max_sick_mask_wearers': 168, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2594, 'max_hosptalized': 1037.6000000000001, 'max_sick_mask_wearers': 168, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2991, 'susceptible': 10, 'total_days': 18, 'max_sick': 2518, 'max_hosptalized': 1007.2, 'max_sick_mask_wearers': 181, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2991, 'susceptible': 10, 'total_days': 18, 'max_sick': 2518, 'max_hosptalized': 1007.2, 'max_sick_mask_wearers': 181, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 19, 'max_sick': 2543, 'max_hosptalized': 1017.2, 'max_sick_mask_wearers': 205, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 19, 'max_sick': 2543, 'max_hosptalized': 1017.2, 'max_sick_mask_wearers': 205, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2498, 'max_hosptalized': 999.2, 'max_sick_mask_wearers': 232, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2498, 'max_hosptalized': 999.2, 'max_sick_mask_wearers': 232, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 18, 'max_sick': 2496, 'max_hosptalized': 998.4000000000001, 'max_sick_mask_wearers': 250, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 18, 'max_sick': 2496, 'max_hosptalized': 998.4000000000001, 'max_sick_mask_wearers': 250, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 18, 'max_sick': 2501, 'max_hosptalized': 1000.4000000000001, 'max_sick_mask_wearers': 275, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 18, 'max_sick': 2501, 'max_hosptalized': 1000.4000000000001, 'max_sick_mask_wearers': 275, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2515, 'max_hosptalized': 1006.0, 'max_sick_mask_wearers': 294, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2515, 'max_hosptalized': 1006.0, 'max_sick_mask_wearers': 294, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 20, 'max_sick': 2485, 'max_hosptalized': 994.0, 'max_sick_mask_wearers': 321, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 20, 'max_sick': 2485, 'max_hosptalized': 994.0, 'max_sick_mask_wearers': 321, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 18, 'max_sick': 2464, 'max_hosptalized': 985.6, 'max_sick_mask_wearers': 342, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 18, 'max_sick': 2464, 'max_hosptalized': 985.6, 'max_sick_mask_wearers': 342, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2990, 'susceptible': 11, 'total_days': 19, 'max_sick': 2457, 'max_hosptalized': 982.8000000000001, 'max_sick_mask_wearers': 376, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2990, 'susceptible': 11, 'total_days': 19, 'max_sick': 2457, 'max_hosptalized': 982.8000000000001, 'max_sick_mask_wearers': 376, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 24, 'max_sick': 2450, 'max_hosptalized': 980.0, 'max_sick_mask_wearers': 391, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 24, 'max_sick': 2450, 'max_hosptalized': 980.0, 'max_sick_mask_wearers': 391, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2989, 'susceptible': 12, 'total_days': 20, 'max_sick': 2433, 'max_hosptalized': 973.2, 'max_sick_mask_wearers': 411, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2989, 'susceptible': 12, 'total_days': 20, 'max_sick': 2433, 'max_hosptalized': 973.2, 'max_sick_mask_wearers': 411, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2985, 'susceptible': 16, 'total_days': 18, 'max_sick': 2398, 'max_hosptalized': 959.2, 'max_sick_mask_wearers': 438, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 1, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2985, 'susceptible': 16, 'total_days': 18, 'max_sick': 2398, 'max_hosptalized': 959.2, 'max_sick_mask_wearers': 438, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 19, 'max_sick': 2589, 'max_hosptalized': 1035.6000000000001, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 19, 'max_sick': 2589, 'max_hosptalized': 1035.6000000000001, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 19, 'max_sick': 2574, 'max_hosptalized': 1029.6000000000001, 'max_sick_mask_wearers': 29, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 19, 'max_sick': 2574, 'max_hosptalized': 1029.6000000000001, 'max_sick_mask_wearers': 29, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2546, 'max_hosptalized': 1018.4000000000001, 'max_sick_mask_wearers': 52, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2546, 'max_hosptalized': 1018.4000000000001, 'max_sick_mask_wearers': 52, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 3000, 'susceptible': 1, 'total_days': 17, 'max_sick': 2561, 'max_hosptalized': 1024.4, 'max_sick_mask_wearers': 70, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 3000, 'susceptible': 1, 'total_days': 17, 'max_sick': 2561, 'max_hosptalized': 1024.4, 'max_sick_mask_wearers': 70, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2524, 'max_hosptalized': 1009.6, 'max_sick_mask_wearers': 90, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2524, 'max_hosptalized': 1009.6, 'max_sick_mask_wearers': 90, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2586, 'max_hosptalized': 1034.4, 'max_sick_mask_wearers': 116, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2586, 'max_hosptalized': 1034.4, 'max_sick_mask_wearers': 116, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 18, 'max_sick': 2512, 'max_hosptalized': 1004.8000000000001, 'max_sick_mask_wearers': 143, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 18, 'max_sick': 2512, 'max_hosptalized': 1004.8000000000001, 'max_sick_mask_wearers': 143, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 19, 'max_sick': 2487, 'max_hosptalized': 994.8000000000001, 'max_sick_mask_wearers': 156, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 19, 'max_sick': 2487, 'max_hosptalized': 994.8000000000001, 'max_sick_mask_wearers': 156, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 17, 'max_sick': 2540, 'max_hosptalized': 1016.0, 'max_sick_mask_wearers': 190, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 17, 'max_sick': 2540, 'max_hosptalized': 1016.0, 'max_sick_mask_wearers': 190, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2990, 'susceptible': 11, 'total_days': 18, 'max_sick': 2475, 'max_hosptalized': 990.0, 'max_sick_mask_wearers': 201, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2990, 'susceptible': 11, 'total_days': 18, 'max_sick': 2475, 'max_hosptalized': 990.0, 'max_sick_mask_wearers': 201, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2989, 'susceptible': 12, 'total_days': 17, 'max_sick': 2568, 'max_hosptalized': 1027.2, 'max_sick_mask_wearers': 241, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2989, 'susceptible': 12, 'total_days': 17, 'max_sick': 2568, 'max_hosptalized': 1027.2, 'max_sick_mask_wearers': 241, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 19, 'max_sick': 2545, 'max_hosptalized': 1018.0, 'max_sick_mask_wearers': 260, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 19, 'max_sick': 2545, 'max_hosptalized': 1018.0, 'max_sick_mask_wearers': 260, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2990, 'susceptible': 11, 'total_days': 19, 'max_sick': 2485, 'max_hosptalized': 994.0, 'max_sick_mask_wearers': 273, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2990, 'susceptible': 11, 'total_days': 19, 'max_sick': 2485, 'max_hosptalized': 994.0, 'max_sick_mask_wearers': 273, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2530, 'max_hosptalized': 1012.0, 'max_sick_mask_wearers': 298, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2530, 'max_hosptalized': 1012.0, 'max_sick_mask_wearers': 298, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 18, 'max_sick': 2452, 'max_hosptalized': 980.8000000000001, 'max_sick_mask_wearers': 322, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 18, 'max_sick': 2452, 'max_hosptalized': 980.8000000000001, 'max_sick_mask_wearers': 322, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 19, 'max_sick': 2513, 'max_hosptalized': 1005.2, 'max_sick_mask_wearers': 352, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 19, 'max_sick': 2513, 'max_hosptalized': 1005.2, 'max_sick_mask_wearers': 352, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 19, 'max_sick': 2442, 'max_hosptalized': 976.8000000000001, 'max_sick_mask_wearers': 372, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 19, 'max_sick': 2442, 'max_hosptalized': 976.8000000000001, 'max_sick_mask_wearers': 372, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 19, 'max_sick': 2446, 'max_hosptalized': 978.4000000000001, 'max_sick_mask_wearers': 387, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 19, 'max_sick': 2446, 'max_hosptalized': 978.4000000000001, 'max_sick_mask_wearers': 387, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 20, 'max_sick': 2480, 'max_hosptalized': 992.0, 'max_sick_mask_wearers': 423, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 20, 'max_sick': 2480, 'max_hosptalized': 992.0, 'max_sick_mask_wearers': 423, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 19, 'max_sick': 2462, 'max_hosptalized': 984.8000000000001, 'max_sick_mask_wearers': 441, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 2, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 19, 'max_sick': 2462, 'max_hosptalized': 984.8000000000001, 'max_sick_mask_wearers': 441, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 16, 'max_sick': 2552, 'max_hosptalized': 1020.8000000000001, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 16, 'max_sick': 2552, 'max_hosptalized': 1020.8000000000001, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2579, 'max_hosptalized': 1031.6000000000001, 'max_sick_mask_wearers': 27, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2579, 'max_hosptalized': 1031.6000000000001, 'max_sick_mask_wearers': 27, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 3001, 'susceptible': 0, 'total_days': 16, 'max_sick': 2594, 'max_hosptalized': 1037.6000000000001, 'max_sick_mask_wearers': 46, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 3001, 'susceptible': 0, 'total_days': 16, 'max_sick': 2594, 'max_hosptalized': 1037.6000000000001, 'max_sick_mask_wearers': 46, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 18, 'max_sick': 2604, 'max_hosptalized': 1041.6000000000001, 'max_sick_mask_wearers': 72, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 18, 'max_sick': 2604, 'max_hosptalized': 1041.6000000000001, 'max_sick_mask_wearers': 72, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 17, 'max_sick': 2602, 'max_hosptalized': 1040.8, 'max_sick_mask_wearers': 101, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 17, 'max_sick': 2602, 'max_hosptalized': 1040.8, 'max_sick_mask_wearers': 101, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2568, 'max_hosptalized': 1027.2, 'max_sick_mask_wearers': 111, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2568, 'max_hosptalized': 1027.2, 'max_sick_mask_wearers': 111, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 18, 'max_sick': 2594, 'max_hosptalized': 1037.6000000000001, 'max_sick_mask_wearers': 150, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 18, 'max_sick': 2594, 'max_hosptalized': 1037.6000000000001, 'max_sick_mask_wearers': 150, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 17, 'max_sick': 2583, 'max_hosptalized': 1033.2, 'max_sick_mask_wearers': 166, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 17, 'max_sick': 2583, 'max_hosptalized': 1033.2, 'max_sick_mask_wearers': 166, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2991, 'susceptible': 10, 'total_days': 18, 'max_sick': 2526, 'max_hosptalized': 1010.4000000000001, 'max_sick_mask_wearers': 188, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2991, 'susceptible': 10, 'total_days': 18, 'max_sick': 2526, 'max_hosptalized': 1010.4000000000001, 'max_sick_mask_wearers': 188, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 18, 'max_sick': 2504, 'max_hosptalized': 1001.6, 'max_sick_mask_wearers': 210, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 18, 'max_sick': 2504, 'max_hosptalized': 1001.6, 'max_sick_mask_wearers': 210, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2545, 'max_hosptalized': 1018.0, 'max_sick_mask_wearers': 244, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2545, 'max_hosptalized': 1018.0, 'max_sick_mask_wearers': 244, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2987, 'susceptible': 14, 'total_days': 18, 'max_sick': 2516, 'max_hosptalized': 1006.4000000000001, 'max_sick_mask_wearers': 248, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2987, 'susceptible': 14, 'total_days': 18, 'max_sick': 2516, 'max_hosptalized': 1006.4000000000001, 'max_sick_mask_wearers': 248, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 3000, 'susceptible': 1, 'total_days': 19, 'max_sick': 2516, 'max_hosptalized': 1006.4000000000001, 'max_sick_mask_wearers': 283, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 3000, 'susceptible': 1, 'total_days': 19, 'max_sick': 2516, 'max_hosptalized': 1006.4000000000001, 'max_sick_mask_wearers': 283, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 17, 'max_sick': 2504, 'max_hosptalized': 1001.6, 'max_sick_mask_wearers': 297, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 17, 'max_sick': 2504, 'max_hosptalized': 1001.6, 'max_sick_mask_wearers': 297, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2481, 'max_hosptalized': 992.4000000000001, 'max_sick_mask_wearers': 334, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2481, 'max_hosptalized': 992.4000000000001, 'max_sick_mask_wearers': 334, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2441, 'max_hosptalized': 976.4000000000001, 'max_sick_mask_wearers': 350, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2441, 'max_hosptalized': 976.4000000000001, 'max_sick_mask_wearers': 350, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 17, 'max_sick': 2504, 'max_hosptalized': 1001.6, 'max_sick_mask_wearers': 380, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 17, 'max_sick': 2504, 'max_hosptalized': 1001.6, 'max_sick_mask_wearers': 380, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2985, 'susceptible': 16, 'total_days': 19, 'max_sick': 2494, 'max_hosptalized': 997.6, 'max_sick_mask_wearers': 401, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2985, 'susceptible': 16, 'total_days': 19, 'max_sick': 2494, 'max_hosptalized': 997.6, 'max_sick_mask_wearers': 401, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 18, 'max_sick': 2398, 'max_hosptalized': 959.2, 'max_sick_mask_wearers': 407, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 18, 'max_sick': 2398, 'max_hosptalized': 959.2, 'max_sick_mask_wearers': 407, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2989, 'susceptible': 12, 'total_days': 19, 'max_sick': 2450, 'max_hosptalized': 980.0, 'max_sick_mask_wearers': 426, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 3, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2989, 'susceptible': 12, 'total_days': 19, 'max_sick': 2450, 'max_hosptalized': 980.0, 'max_sick_mask_wearers': 426, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 16, 'max_sick': 2595, 'max_hosptalized': 1038.0, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 16, 'max_sick': 2595, 'max_hosptalized': 1038.0, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 17, 'max_sick': 2611, 'max_hosptalized': 1044.4, 'max_sick_mask_wearers': 26, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 17, 'max_sick': 2611, 'max_hosptalized': 1044.4, 'max_sick_mask_wearers': 26, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2541, 'max_hosptalized': 1016.4000000000001, 'max_sick_mask_wearers': 46, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2541, 'max_hosptalized': 1016.4000000000001, 'max_sick_mask_wearers': 46, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2643, 'max_hosptalized': 1057.2, 'max_sick_mask_wearers': 77, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2643, 'max_hosptalized': 1057.2, 'max_sick_mask_wearers': 77, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 19, 'max_sick': 2542, 'max_hosptalized': 1016.8000000000001, 'max_sick_mask_wearers': 99, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 19, 'max_sick': 2542, 'max_hosptalized': 1016.8000000000001, 'max_sick_mask_wearers': 99, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 19, 'max_sick': 2546, 'max_hosptalized': 1018.4000000000001, 'max_sick_mask_wearers': 120, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 19, 'max_sick': 2546, 'max_hosptalized': 1018.4000000000001, 'max_sick_mask_wearers': 120, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2553, 'max_hosptalized': 1021.2, 'max_sick_mask_wearers': 140, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2553, 'max_hosptalized': 1021.2, 'max_sick_mask_wearers': 140, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2556, 'max_hosptalized': 1022.4000000000001, 'max_sick_mask_wearers': 171, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2556, 'max_hosptalized': 1022.4000000000001, 'max_sick_mask_wearers': 171, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 17, 'max_sick': 2519, 'max_hosptalized': 1007.6, 'max_sick_mask_wearers': 188, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 17, 'max_sick': 2519, 'max_hosptalized': 1007.6, 'max_sick_mask_wearers': 188, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2991, 'susceptible': 10, 'total_days': 19, 'max_sick': 2544, 'max_hosptalized': 1017.6, 'max_sick_mask_wearers': 215, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 4, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2991, 'susceptible': 10, 'total_days': 19, 'max_sick': 2544, 'max_hosptalized': 1017.6, 'max_sick_mask_wearers': 215, 'total_mask_wearers': 270}
# ...
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2997, 'susceptible': 4, 'total_days': 18, 'max_sick': 2523, 'max_hosptalized': 1009.2, 'max_sick_mask_wearers': 238, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 18, 'max_sick': 2506, 'max_hosptalized': 1002.4000000000001, 'max_sick_mask_wearers': 250, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 18, 'max_sick': 2506, 'max_hosptalized': 1002.4000000000001, 'max_sick_mask_wearers': 250, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 18, 'max_sick': 2473, 'max_hosptalized': 989.2, 'max_sick_mask_wearers': 276, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 18, 'max_sick': 2473, 'max_hosptalized': 989.2, 'max_sick_mask_wearers': 276, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 19, 'max_sick': 2474, 'max_hosptalized': 989.6, 'max_sick_mask_wearers': 295, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 19, 'max_sick': 2474, 'max_hosptalized': 989.6, 'max_sick_mask_wearers': 295, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 19, 'max_sick': 2432, 'max_hosptalized': 972.8000000000001, 'max_sick_mask_wearers': 332, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 19, 'max_sick': 2432, 'max_hosptalized': 972.8000000000001, 'max_sick_mask_wearers': 332, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2985, 'susceptible': 16, 'total_days': 19, 'max_sick': 2464, 'max_hosptalized': 985.6, 'max_sick_mask_wearers': 325, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2985, 'susceptible': 16, 'total_days': 19, 'max_sick': 2464, 'max_hosptalized': 985.6, 'max_sick_mask_wearers': 325, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 18, 'max_sick': 2490, 'max_hosptalized': 996.0, 'max_sick_mask_wearers': 374, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2988, 'susceptible': 13, 'total_days': 18, 'max_sick': 2490, 'max_hosptalized': 996.0, 'max_sick_mask_wearers': 374, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2987, 'susceptible': 14, 'total_days': 18, 'max_sick': 2464, 'max_hosptalized': 985.6, 'max_sick_mask_wearers': 395, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2987, 'susceptible': 14, 'total_days': 18, 'max_sick': 2464, 'max_hosptalized': 985.6, 'max_sick_mask_wearers': 395, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2984, 'susceptible': 17, 'total_days': 18, 'max_sick': 2472, 'max_hosptalized': 988.8000000000001, 'max_sick_mask_wearers': 418, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2984, 'susceptible': 17, 'total_days': 18, 'max_sick': 2472, 'max_hosptalized': 988.8000000000001, 'max_sick_mask_wearers': 418, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 18, 'max_sick': 2492, 'max_hosptalized': 996.8000000000001, 'max_sick_mask_wearers': 416, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 8, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 18, 'max_sick': 2492, 'max_hosptalized': 996.8000000000001, 'max_sick_mask_wearers': 416, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2602, 'max_hosptalized': 1040.8, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 0, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2602, 'max_hosptalized': 1040.8, 'max_sick_mask_wearers': 0, 'total_mask_wearers': 0}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 17, 'max_sick': 2604, 'max_hosptalized': 1041.6000000000001, 'max_sick_mask_wearers': 23, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 1, 'Hospitalization_Rate': 0.4, 'recovered': 2998, 'susceptible': 3, 'total_days': 17, 'max_sick': 2604, 'max_hosptalized': 1041.6000000000001, 'max_sick_mask_wearers': 23, 'total_mask_wearers': 30}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2593, 'max_hosptalized': 1037.2, 'max_sick_mask_wearers': 45, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 2, 'Hospitalization_Rate': 0.4, 'recovered': 2999, 'susceptible': 2, 'total_days': 17, 'max_sick': 2593, 'max_hosptalized': 1037.2, 'max_sick_mask_wearers': 45, 'total_mask_wearers': 60}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 19, 'max_sick': 2523, 'max_hosptalized': 1009.2, 'max_sick_mask_wearers': 71, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 3, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 19, 'max_sick': 2523, 'max_hosptalized': 1009.2, 'max_sick_mask_wearers': 71, 'total_mask_wearers': 90}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 21, 'max_sick': 2565, 'max_hosptalized': 1026.0, 'max_sick_mask_wearers': 97, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 4, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 21, 'max_sick': 2565, 'max_hosptalized': 1026.0, 'max_sick_mask_wearers': 97, 'total_mask_wearers': 120}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2579, 'max_hosptalized': 1031.6000000000001, 'max_sick_mask_wearers': 121, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 5, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 17, 'max_sick': 2579, 'max_hosptalized': 1031.6000000000001, 'max_sick_mask_wearers': 121, 'total_mask_wearers': 150}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2547, 'max_hosptalized': 1018.8000000000001, 'max_sick_mask_wearers': 141, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 6, 'Hospitalization_Rate': 0.4, 'recovered': 2996, 'susceptible': 5, 'total_days': 17, 'max_sick': 2547, 'max_hosptalized': 1018.8000000000001, 'max_sick_mask_wearers': 141, 'total_mask_wearers': 180}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2506, 'max_hosptalized': 1002.4000000000001, 'max_sick_mask_wearers': 173, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 7, 'Hospitalization_Rate': 0.4, 'recovered': 2995, 'susceptible': 6, 'total_days': 18, 'max_sick': 2506, 'max_hosptalized': 1002.4000000000001, 'max_sick_mask_wearers': 173, 'total_mask_wearers': 211}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 17, 'max_sick': 2559, 'max_hosptalized': 1023.6, 'max_sick_mask_wearers': 179, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 8, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 17, 'max_sick': 2559, 'max_hosptalized': 1023.6, 'max_sick_mask_wearers': 179, 'total_mask_wearers': 240}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 18, 'max_sick': 2496, 'max_hosptalized': 998.4000000000001, 'max_sick_mask_wearers': 211, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 9, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 18, 'max_sick': 2496, 'max_hosptalized': 998.4000000000001, 'max_sick_mask_wearers': 211, 'total_mask_wearers': 270}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 18, 'max_sick': 2541, 'max_hosptalized': 1016.4000000000001, 'max_sick_mask_wearers': 246, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 10, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 18, 'max_sick': 2541, 'max_hosptalized': 1016.4000000000001, 'max_sick_mask_wearers': 246, 'total_mask_wearers': 300}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2984, 'susceptible': 17, 'total_days': 18, 'max_sick': 2533, 'max_hosptalized': 1013.2, 'max_sick_mask_wearers': 256, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 11, 'Hospitalization_Rate': 0.4, 'recovered': 2984, 'susceptible': 17, 'total_days': 18, 'max_sick': 2533, 'max_hosptalized': 1013.2, 'max_sick_mask_wearers': 256, 'total_mask_wearers': 330}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 19, 'max_sick': 2475, 'max_hosptalized': 990.0, 'max_sick_mask_wearers': 293, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 12, 'Hospitalization_Rate': 0.4, 'recovered': 2993, 'susceptible': 8, 'total_days': 19, 'max_sick': 2475, 'max_hosptalized': 990.0, 'max_sick_mask_wearers': 293, 'total_mask_wearers': 360}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 19, 'max_sick': 2476, 'max_hosptalized': 990.4000000000001, 'max_sick_mask_wearers': 307, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 13, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 19, 'max_sick': 2476, 'max_hosptalized': 990.4000000000001, 'max_sick_mask_wearers': 307, 'total_mask_wearers': 390}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 17, 'max_sick': 2529, 'max_hosptalized': 1011.6, 'max_sick_mask_wearers': 324, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 14, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 17, 'max_sick': 2529, 'max_hosptalized': 1011.6, 'max_sick_mask_wearers': 324, 'total_mask_wearers': 421}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2464, 'max_hosptalized': 985.6, 'max_sick_mask_wearers': 350, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 15, 'Hospitalization_Rate': 0.4, 'recovered': 2994, 'susceptible': 7, 'total_days': 18, 'max_sick': 2464, 'max_hosptalized': 985.6, 'max_sick_mask_wearers': 350, 'total_mask_wearers': 450}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 21, 'max_sick': 2494, 'max_hosptalized': 997.6, 'max_sick_mask_wearers': 362, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 16, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 21, 'max_sick': 2494, 'max_hosptalized': 997.6, 'max_sick_mask_wearers': 362, 'total_mask_wearers': 480}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 21, 'max_sick': 2468, 'max_hosptalized': 987.2, 'max_sick_mask_wearers': 398, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 17, 'Hospitalization_Rate': 0.4, 'recovered': 2992, 'susceptible': 9, 'total_days': 21, 'max_sick': 2468, 'max_hosptalized': 987.2, 'max_sick_mask_wearers': 398, 'total_mask_wearers': 511}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 18, 'max_sick': 2486, 'max_hosptalized': 994.4000000000001, 'max_sick_mask_wearers': 416, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 18, 'Hospitalization_Rate': 0.4, 'recovered': 2986, 'susceptible': 15, 'total_days': 18, 'max_sick': 2486, 'max_hosptalized': 994.4000000000001, 'max_sick_mask_wearers': 416, 'total_mask_wearers': 540}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2985, 'susceptible': 16, 'total_days': 18, 'max_sick': 2444, 'max_hosptalized': 977.6, 'max_sick_mask_wearers': 438, 'total_mask_wearers': 570}
# {'Population_Size': 3000, 'Number_Interactions': 9, 'Percentage_Masked': 19, 'Hospitalization_Rate': 0.4, 'recovered': 2985, 'susceptible': 16, 'total_days': 18, 'max_sick': 2444, 'max_hosptalized': 977.6, 'max_sick_mask_wearers': 438, 'total_mask_wearers': 570}
